# %%
# Import the random module.
import random

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Turn zipped tuples into a list of coordinates.
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dunedin
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | tadine
# Processing Record 6 of Set 1 | plettenberg bay
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | goderich
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | acarau
# Processing Record 12 of Set 1 | basco
# Processing Record 13 of Set 1 | lagos
# Processing Record 14 of Set 1 | naze
# Processing Record 15 of Set 1 | hervey bay
# Processing Record 16 of Set 1 | ilsede
# Processing Record 17 of Set 1 | chulman
# Processing Record 18 of Set 1 | port lincoln
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | daru
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | terrace
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | karratha
# Processing Record 26 of Set 1 | ugoofaaru
# Processing Record 27 of Set 1 | flinders
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | thompson
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | half moon bay
# Processing Record 33 of Set 1 | gizo
# Processing Record 34 of Set 1 | mishan
# Processing Record 35 of Set 1 | lubu
# Processing Record 36 of Set 1 | shingu
# Processing Record 37 of Set 1 | morondava
# Processing Record 38 of Set 1 | port hedland
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | beloha
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | port hardy
# Processing Record 50 of Set 1 | jaisalmer
# Processing Record 1 of Set 2 | south river
# Processing Record 2 of Set 2 | chapais
# Processing Record 3 of Set 2 | saint-joseph
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | ahuimanu
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | pontianak
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | teknaf
# Processing Record 10 of Set 2 | aksarka
# Processing Record 11 of Set 2 | nagato
# Processing Record 12 of Set 2 | carutapera
# Processing Record 13 of Set 2 | joao pinheiro
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | warrington
# Processing Record 16 of Set 2 | hambantota
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | kefamenanu
# Processing Record 19 of Set 2 | kemijarvi
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | aklavik
# Processing Record 22 of Set 2 | rizhao
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | bajo baudo
# City not found. Skipping...
# Processing Record 25 of Set 2 | invermere
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | taveta
# Processing Record 28 of Set 2 | bilkha
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 2 | san quintin
# Processing Record 31 of Set 2 | busselton
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | kruisfontein
# Processing Record 34 of Set 2 | maceio
# Processing Record 35 of Set 2 | axim
# Processing Record 36 of Set 2 | andilamena
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | dingle
# Processing Record 39 of Set 2 | ahipara
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | beringovskiy
# Processing Record 42 of Set 2 | nome
# Processing Record 43 of Set 2 | hami
# Processing Record 44 of Set 2 | sao filipe
# Processing Record 45 of Set 2 | kodiak
# Processing Record 46 of Set 2 | pangody
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | dolores
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 50 of Set 2 | cururupu
# Processing Record 1 of Set 3 | dubrovka
# Processing Record 2 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 3 | cap malheureux
# Processing Record 4 of Set 3 | luderitz
# Processing Record 5 of Set 3 | shimoda
# Processing Record 6 of Set 3 | kaseda
# Processing Record 7 of Set 3 | kintampo
# Processing Record 8 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 3 | namatanai
# Processing Record 10 of Set 3 | najran
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | maragogi
# Processing Record 13 of Set 3 | airai
# Processing Record 14 of Set 3 | novooleksiyivka
# Processing Record 15 of Set 3 | hasaki
# Processing Record 16 of Set 3 | bluff
# Processing Record 17 of Set 3 | leningradskiy
# Processing Record 18 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | katsuura
# Processing Record 22 of Set 3 | krasnorechenskiy
# Processing Record 23 of Set 3 | bandarbeyla
# Processing Record 24 of Set 3 | coahuayana
# Processing Record 25 of Set 3 | popondetta
# Processing Record 26 of Set 3 | hun
# Processing Record 27 of Set 3 | pekan
# Processing Record 28 of Set 3 | beaver falls
# Processing Record 29 of Set 3 | mecca
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | jardim
# Processing Record 33 of Set 3 | kieta
# Processing Record 34 of Set 3 | assare
# Processing Record 35 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 3 | alta floresta
# Processing Record 37 of Set 3 | cabo san lucas
# Processing Record 38 of Set 3 | kiunga
# Processing Record 39 of Set 3 | coihueco
# Processing Record 40 of Set 3 | kamenka
# Processing Record 41 of Set 3 | nybro
# Processing Record 42 of Set 3 | locorotondo
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | matagami
# Processing Record 45 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 3 | osoyoos
# Processing Record 47 of Set 3 | olafsvik
# Processing Record 48 of Set 3 | tezu
# Processing Record 49 of Set 3 | lompoc
# Processing Record 50 of Set 3 | dikson
# Processing Record 1 of Set 4 | yellowknife
# Processing Record 2 of Set 4 | klaksvik
# Processing Record 3 of Set 4 | jamestown
# Processing Record 4 of Set 4 | yelatma
# Processing Record 5 of Set 4 | leopold
# Processing Record 6 of Set 4 | launceston
# Processing Record 7 of Set 4 | arkhangelsk
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | tuy hoa
# Processing Record 10 of Set 4 | bredasdorp
# Processing Record 11 of Set 4 | parlakimidi
# Processing Record 12 of Set 4 | lalmohan
# Processing Record 13 of Set 4 | da nang
# Processing Record 14 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 4 | korla
# Processing Record 16 of Set 4 | jasper
# Processing Record 17 of Set 4 | pisco
# Processing Record 18 of Set 4 | kilindoni
# Processing Record 19 of Set 4 | dhidhdhoo
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | pauini
# Processing Record 23 of Set 4 | payson
# Processing Record 24 of Set 4 | finnsnes
# Processing Record 25 of Set 4 | port alfred
# Processing Record 26 of Set 4 | columbus
# Processing Record 27 of Set 4 | vila franca do campo
# Processing Record 28 of Set 4 | la palma
# Processing Record 29 of Set 4 | broome
# Processing Record 30 of Set 4 | seoul
# Processing Record 31 of Set 4 | vaini
# Processing Record 32 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 33 of Set 4 | pavlikeni
# Processing Record 34 of Set 4 | manuk mangkaw
# Processing Record 35 of Set 4 | taphan hin
# Processing Record 36 of Set 4 | mar del plata
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | lebu
# Processing Record 39 of Set 4 | amga
# Processing Record 40 of Set 4 | kahului
# Processing Record 41 of Set 4 | margate
# Processing Record 42 of Set 4 | suzu
# City not found. Skipping...
# Processing Record 43 of Set 4 | port-gentil
# Processing Record 44 of Set 4 | chuy
# Processing Record 45 of Set 4 | isangel
# Processing Record 46 of Set 4 | tura
# Processing Record 47 of Set 4 | butaritari
# Processing Record 48 of Set 4 | alofi
# Processing Record 49 of Set 4 | lubango
# Processing Record 50 of Set 4 | bathsheba
# Processing Record 1 of Set 5 | sokolac
# Processing Record 2 of Set 5 | santa maria del oro
# Processing Record 3 of Set 5 | grindavik
# Processing Record 4 of Set 5 | burica
# City not found. Skipping...
# Processing Record 5 of Set 5 | qingan
# City not found. Skipping...
# Processing Record 6 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 5 | kuldur
# Processing Record 8 of Set 5 | shush
# Processing Record 9 of Set 5 | kualakapuas
# Processing Record 10 of Set 5 | rapid valley
# Processing Record 11 of Set 5 | mgandu
# Processing Record 12 of Set 5 | koboldo
# City not found. Skipping...
# Processing Record 13 of Set 5 | lingao
# Processing Record 14 of Set 5 | wuchang
# Processing Record 15 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 16 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 5 | bosaso
# Processing Record 18 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 5 | ternate
# Processing Record 20 of Set 5 | codrington
# Processing Record 21 of Set 5 | obera
# Processing Record 22 of Set 5 | brighton
# Processing Record 23 of Set 5 | adre
# Processing Record 24 of Set 5 | usinsk
# Processing Record 25 of Set 5 | bonavista
# Processing Record 26 of Set 5 | hashimoto
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 5 | nyagan
# Processing Record 29 of Set 5 | sur
# Processing Record 30 of Set 5 | havre-saint-pierre
# Processing Record 31 of Set 5 | marathon
# Processing Record 32 of Set 5 | sioux lookout
# Processing Record 33 of Set 5 | belmonte
# Processing Record 34 of Set 5 | palmas de monte alto
# Processing Record 35 of Set 5 | havelock
# Processing Record 36 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 5 | shenxian
# Processing Record 38 of Set 5 | sendhwa
# Processing Record 39 of Set 5 | zhongxing
# Processing Record 40 of Set 5 | nadym
# Processing Record 41 of Set 5 | henties bay
# Processing Record 42 of Set 5 | satipo
# Processing Record 43 of Set 5 | el estor
# Processing Record 44 of Set 5 | jacqueville
# Processing Record 45 of Set 5 | guilin
# Processing Record 46 of Set 5 | makasar
# Processing Record 47 of Set 5 | usoke
# Processing Record 48 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | nandu
# Processing Record 50 of Set 5 | antofagasta
# Processing Record 1 of Set 6 | victoria
# Processing Record 2 of Set 6 | rio gallegos
# Processing Record 3 of Set 6 | wewak
# Processing Record 4 of Set 6 | maniitsoq
# Processing Record 5 of Set 6 | berdigestyakh
# Processing Record 6 of Set 6 | yuanping
# Processing Record 7 of Set 6 | pizarro
# Processing Record 8 of Set 6 | lorengau
# Processing Record 9 of Set 6 | atar
# Processing Record 10 of Set 6 | sitka
# Processing Record 11 of Set 6 | asyut
# Processing Record 12 of Set 6 | jinka
# Processing Record 13 of Set 6 | celestun
# Processing Record 14 of Set 6 | altamira
# Processing Record 15 of Set 6 | geraldton
# Processing Record 16 of Set 6 | provideniya
# Processing Record 17 of Set 6 | praya
# Processing Record 18 of Set 6 | vardo
# Processing Record 19 of Set 6 | port hawkesbury
# Processing Record 20 of Set 6 | samarai
# Processing Record 21 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 6 | hata
# Processing Record 23 of Set 6 | lasa
# Processing Record 24 of Set 6 | hirara
# Processing Record 25 of Set 6 | mindelo
# Processing Record 26 of Set 6 | aquiraz
# Processing Record 27 of Set 6 | harper
# Processing Record 28 of Set 6 | gushikawa
# Processing Record 29 of Set 6 | gazli
# Processing Record 30 of Set 6 | severo-kurilsk
# Processing Record 31 of Set 6 | namtsy
# Processing Record 32 of Set 6 | upernavik
# Processing Record 33 of Set 6 | san francisco
# Processing Record 34 of Set 6 | ixtapa
# Processing Record 35 of Set 6 | tanete
# Processing Record 36 of Set 6 | orange
# Processing Record 37 of Set 6 | cabedelo
# Processing Record 38 of Set 6 | fallon
# Processing Record 39 of Set 6 | skegness
# Processing Record 40 of Set 6 | xunchang
# Processing Record 41 of Set 6 | whyalla
# Processing Record 42 of Set 6 | ketchikan
# Processing Record 43 of Set 6 | tiarei
# Processing Record 44 of Set 6 | pitkyaranta
# Processing Record 45 of Set 6 | santa marta de tormes
# Processing Record 46 of Set 6 | itupiranga
# Processing Record 47 of Set 6 | koutiala
# Processing Record 48 of Set 6 | almaznyy
# Processing Record 49 of Set 6 | moree
# Processing Record 50 of Set 6 | baykit
# Processing Record 1 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 2 of Set 7 | madimba
# Processing Record 3 of Set 7 | kimbe
# Processing Record 4 of Set 7 | portland
# Processing Record 5 of Set 7 | iqaluit
# Processing Record 6 of Set 7 | san carlos
# Processing Record 7 of Set 7 | wanning
# Processing Record 8 of Set 7 | ilulissat
# Processing Record 9 of Set 7 | moose factory
# Processing Record 10 of Set 7 | malim
# Processing Record 11 of Set 7 | mahanoro
# Processing Record 12 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 7 | virden
# Processing Record 14 of Set 7 | millinocket
# Processing Record 15 of Set 7 | saint-georges
# Processing Record 16 of Set 7 | merksplas
# Processing Record 17 of Set 7 | coquimbo
# Processing Record 18 of Set 7 | kuliyapitiya
# Processing Record 19 of Set 7 | linhares
# Processing Record 20 of Set 7 | buala
# Processing Record 21 of Set 7 | college
# Processing Record 22 of Set 7 | meulaboh
# Processing Record 23 of Set 7 | paracuru
# Processing Record 24 of Set 7 | kendari
# Processing Record 25 of Set 7 | pangnirtung
# Processing Record 26 of Set 7 | qaanaaq
# Processing Record 27 of Set 7 | mama
# Processing Record 28 of Set 7 | tuatapere
# Processing Record 29 of Set 7 | abaza
# Processing Record 30 of Set 7 | north bend
# Processing Record 31 of Set 7 | roald
# Processing Record 32 of Set 7 | tautira
# Processing Record 33 of Set 7 | pingliang
# Processing Record 34 of Set 7 | touros
# Processing Record 35 of Set 7 | lishui
# Processing Record 36 of Set 7 | paita
# Processing Record 37 of Set 7 | temascalcingo
# Processing Record 38 of Set 7 | puerto leguizamo
# Processing Record 39 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 7 | cayenne
# Processing Record 41 of Set 7 | wattegama
# Processing Record 42 of Set 7 | harnosand
# Processing Record 43 of Set 7 | santa vitoria do palmar
# Processing Record 44 of Set 7 | salalah
# Processing Record 45 of Set 7 | saldanha
# Processing Record 46 of Set 7 | kropotkin
# Processing Record 47 of Set 7 | tilichiki
# Processing Record 48 of Set 7 | talnakh
# Processing Record 49 of Set 7 | richards bay
# Processing Record 50 of Set 7 | papasquiaro
# City not found. Skipping...
# Processing Record 1 of Set 8 | chaman
# Processing Record 2 of Set 8 | port moresby
# Processing Record 3 of Set 8 | prince rupert
# Processing Record 4 of Set 8 | bloemfontein
# Processing Record 5 of Set 8 | yulara
# Processing Record 6 of Set 8 | ulaangom
# Processing Record 7 of Set 8 | andenes
# Processing Record 8 of Set 8 | mahebourg
# Processing Record 9 of Set 8 | hamilton
# Processing Record 10 of Set 8 | angicos
# Processing Record 11 of Set 8 | anadyr
# Processing Record 12 of Set 8 | merauke
# Processing Record 13 of Set 8 | koshurnikovo
# Processing Record 14 of Set 8 | havoysund
# Processing Record 15 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 8 | caluquembe
# Processing Record 17 of Set 8 | myre
# Processing Record 18 of Set 8 | walvis bay
# Processing Record 19 of Set 8 | el porvenir
# Processing Record 20 of Set 8 | la rioja
# Processing Record 21 of Set 8 | awbari
# Processing Record 22 of Set 8 | tongchuan
# Processing Record 23 of Set 8 | westport
# Processing Record 24 of Set 8 | guerrero negro
# Processing Record 25 of Set 8 | morehead
# Processing Record 26 of Set 8 | port augusta
# Processing Record 27 of Set 8 | acapulco
# Processing Record 28 of Set 8 | mount isa
# Processing Record 29 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 8 | kovdor
# Processing Record 31 of Set 8 | ust-omchug
# Processing Record 32 of Set 8 | bela
# Processing Record 33 of Set 8 | pochutla
# Processing Record 34 of Set 8 | san cristobal
# Processing Record 35 of Set 8 | bayan
# Processing Record 36 of Set 8 | gat
# Processing Record 37 of Set 8 | los llanos de aridane
# Processing Record 38 of Set 8 | komsomolskiy
# Processing Record 39 of Set 8 | faanui
# Processing Record 40 of Set 8 | yining
# Processing Record 41 of Set 8 | calderitas
# Processing Record 42 of Set 8 | namie
# Processing Record 43 of Set 8 | marsa matruh
# Processing Record 44 of Set 8 | moulmeingyun
# City not found. Skipping...
# Processing Record 45 of Set 8 | nanzhang
# Processing Record 46 of Set 8 | kavieng
# Processing Record 47 of Set 8 | nichinan
# Processing Record 48 of Set 8 | turukhansk
# Processing Record 49 of Set 8 | kashi
# Processing Record 50 of Set 8 | torbay
# Processing Record 1 of Set 9 | naryan-mar
# Processing Record 2 of Set 9 | matara
# Processing Record 3 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 4 of Set 9 | imbituba
# Processing Record 5 of Set 9 | san policarpo
# Processing Record 6 of Set 9 | san andres del rabanedo
# Processing Record 7 of Set 9 | zapolyarnyy
# Processing Record 8 of Set 9 | giresun
# Processing Record 9 of Set 9 | bethel
# Processing Record 10 of Set 9 | mountain home
# Processing Record 11 of Set 9 | sibolga
# Processing Record 12 of Set 9 | berlevag
# Processing Record 13 of Set 9 | dongkan
# Processing Record 14 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 9 | pizhma
# Processing Record 16 of Set 9 | aswan
# Processing Record 17 of Set 9 | santa maria do para
# Processing Record 18 of Set 9 | nieuw amsterdam
# Processing Record 19 of Set 9 | sept-iles
# Processing Record 20 of Set 9 | garowe
# Processing Record 21 of Set 9 | fortuna
# Processing Record 22 of Set 9 | san onofre
# Processing Record 23 of Set 9 | sozimskiy
# Processing Record 24 of Set 9 | kidal
# Processing Record 25 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 26 of Set 9 | yenagoa
# Processing Record 27 of Set 9 | russell
# Processing Record 28 of Set 9 | lavrentiya
# Processing Record 29 of Set 9 | knyaze-volkonskoye
# Processing Record 30 of Set 9 | shenjiamen
# Processing Record 31 of Set 9 | nizwa
# Processing Record 32 of Set 9 | narsaq
# Processing Record 33 of Set 9 | thoen
# Processing Record 34 of Set 9 | bud
# Processing Record 35 of Set 9 | kununurra
# Processing Record 36 of Set 9 | nanortalik
# Processing Record 37 of Set 9 | ust-koksa
# Processing Record 38 of Set 9 | avera
# Processing Record 39 of Set 9 | bengkulu
# Processing Record 40 of Set 9 | lavumisa
# Processing Record 41 of Set 9 | menongue
# Processing Record 42 of Set 9 | malakal
# Processing Record 43 of Set 9 | tabuk
# Processing Record 44 of Set 9 | vostok
# Processing Record 45 of Set 9 | abalak
# Processing Record 46 of Set 9 | muros
# Processing Record 47 of Set 9 | tacoronte
# Processing Record 48 of Set 9 | eyl
# Processing Record 49 of Set 9 | manggar
# Processing Record 50 of Set 9 | vittoria
# Processing Record 1 of Set 10 | oranjemund
# Processing Record 2 of Set 10 | dromolaxia
# Processing Record 3 of Set 10 | dongsheng
# Processing Record 4 of Set 10 | santa rosa
# Processing Record 5 of Set 10 | praia da vitoria
# Processing Record 6 of Set 10 | xam nua
# Processing Record 7 of Set 10 | arman
# Processing Record 8 of Set 10 | leczyca
# Processing Record 9 of Set 10 | haines city
# Processing Record 10 of Set 10 | broken hill
# Processing Record 11 of Set 10 | sorland
# Processing Record 12 of Set 10 | algeciras
# Processing Record 13 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 10 | xinyu
# Processing Record 15 of Set 10 | wismar
# Processing Record 16 of Set 10 | saint-louis
# Processing Record 17 of Set 10 | katha
# City not found. Skipping...
# Processing Record 18 of Set 10 | morros
# Processing Record 19 of Set 10 | pundaguitan
# Processing Record 20 of Set 10 | gigmoto
# Processing Record 21 of Set 10 | bouca
# Processing Record 22 of Set 10 | stephenville
# Processing Record 23 of Set 10 | forrest city
# Processing Record 24 of Set 10 | puerto del rosario
# Processing Record 25 of Set 10 | sobolevo
# Processing Record 26 of Set 10 | egvekinot
# Processing Record 27 of Set 10 | pacific grove
# Processing Record 28 of Set 10 | muromtsevo
# Processing Record 29 of Set 10 | hualmay
# Processing Record 30 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 31 of Set 10 | ancud
# Processing Record 32 of Set 10 | podor
# Processing Record 33 of Set 10 | namibe
# Processing Record 34 of Set 10 | bambous virieux
# Processing Record 35 of Set 10 | kirkuk
# Processing Record 36 of Set 10 | saint george
# Processing Record 37 of Set 10 | nantucket
# Processing Record 38 of Set 10 | gazanjyk
# Processing Record 39 of Set 10 | sosnovo-ozerskoye
# Processing Record 40 of Set 10 | ilhabela
# Processing Record 41 of Set 10 | husavik
# Processing Record 42 of Set 10 | lazaro cardenas
# Processing Record 43 of Set 10 | batagay
# Processing Record 44 of Set 10 | poronaysk
# Processing Record 45 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 10 | mehamn
# Processing Record 47 of Set 10 | constitucion
# Processing Record 48 of Set 10 | esperance
# Processing Record 49 of Set 10 | sheltozero
# Processing Record 50 of Set 10 | marienburg
# Processing Record 1 of Set 11 | turayf
# Processing Record 2 of Set 11 | san juan
# Processing Record 3 of Set 11 | cordoba
# Processing Record 4 of Set 11 | fairbanks
# Processing Record 5 of Set 11 | vanimo
# Processing Record 6 of Set 11 | salekhard
# Processing Record 7 of Set 11 | manokwari
# Processing Record 8 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 11 | calama
# Processing Record 10 of Set 11 | riyadh
# Processing Record 11 of Set 11 | dafeng
# Processing Record 12 of Set 11 | sao joao da barra
# Processing Record 13 of Set 11 | kupino
# Processing Record 14 of Set 11 | blackfoot
# Processing Record 15 of Set 11 | matelica
# Processing Record 16 of Set 11 | laguna
# Processing Record 17 of Set 11 | madaba
# Processing Record 18 of Set 11 | arys
# Processing Record 19 of Set 11 | dublin
# Processing Record 20 of Set 11 | inuvik
# Processing Record 21 of Set 11 | kushima
# Processing Record 22 of Set 11 | hof
# Processing Record 23 of Set 11 | flin flon
# Processing Record 24 of Set 11 | kedrovyy
# Processing Record 25 of Set 11 | siniscola
# Processing Record 26 of Set 11 | xai-xai
# Processing Record 27 of Set 11 | koulamoutou
# Processing Record 28 of Set 11 | the valley
# Processing Record 29 of Set 11 | rocha
# Processing Record 30 of Set 11 | adrar
# Processing Record 31 of Set 11 | sola
# Processing Record 32 of Set 11 | mayo
# Processing Record 33 of Set 11 | valdivia
# Processing Record 34 of Set 11 | sonder bjert
# Processing Record 35 of Set 11 | cherskiy
# Processing Record 36 of Set 11 | ossora
# Processing Record 37 of Set 11 | lagoa
# Processing Record 38 of Set 11 | minab
# Processing Record 39 of Set 11 | partapur
# Processing Record 40 of Set 11 | grand baie
# Processing Record 41 of Set 11 | baherden
# Processing Record 42 of Set 11 | hitoyoshi
# Processing Record 43 of Set 11 | ust-maya
# Processing Record 44 of Set 11 | panguna
# Processing Record 45 of Set 11 | hay river
# Processing Record 46 of Set 11 | la oroya
# Processing Record 47 of Set 11 | redcliffe
# Processing Record 48 of Set 11 | tigre
# Processing Record 49 of Set 11 | te anau
# Processing Record 50 of Set 11 | puerto carreno
# Processing Record 1 of Set 12 | almeirim
# Processing Record 2 of Set 12 | kyren
# Processing Record 3 of Set 12 | bubaque
# Processing Record 4 of Set 12 | griffith
# Processing Record 5 of Set 12 | talaya
# Processing Record 6 of Set 12 | kangaatsiaq
# Processing Record 7 of Set 12 | graaff-reinet
# Processing Record 8 of Set 12 | meylan
# Processing Record 9 of Set 12 | nara
# Processing Record 10 of Set 12 | otradnoye
# Processing Record 11 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 12 | ghanzi
# Processing Record 13 of Set 12 | coffeyville
# Processing Record 14 of Set 12 | jerantut
# Processing Record 15 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 16 of Set 12 | laukaa
# Processing Record 17 of Set 12 | teofilo otoni
# Processing Record 18 of Set 12 | capao da canoa
# Processing Record 19 of Set 12 | khawhai
# Processing Record 20 of Set 12 | woodstock
# Processing Record 21 of Set 12 | jalu
# Processing Record 22 of Set 12 | bauchi
# Processing Record 23 of Set 12 | ulladulla
# Processing Record 24 of Set 12 | mendi
# Processing Record 25 of Set 12 | whitehorse
# Processing Record 26 of Set 12 | oistins
# Processing Record 27 of Set 12 | macedo de cavaleiros
# Processing Record 28 of Set 12 | surgut
# Processing Record 29 of Set 12 | asfi
# Processing Record 30 of Set 12 | banda aceh
# Processing Record 31 of Set 12 | pesqueira
# Processing Record 32 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 33 of Set 12 | puerto madero
# Processing Record 34 of Set 12 | moissala
# Processing Record 35 of Set 12 | presidencia roque saenz pena
# Processing Record 36 of Set 12 | okha
# Processing Record 37 of Set 12 | nishihara
# Processing Record 38 of Set 12 | lamesa
# Processing Record 39 of Set 12 | yarmolyntsi
# Processing Record 40 of Set 12 | zhanaozen
# Processing Record 41 of Set 12 | thunder bay
# Processing Record 42 of Set 12 | naron
# Processing Record 43 of Set 12 | beverley
# Processing Record 44 of Set 12 | muravlenko
# Processing Record 45 of Set 12 | felanitx
# Processing Record 46 of Set 12 | la ronge
# Processing Record 47 of Set 12 | baruun-urt
# Processing Record 48 of Set 12 | concepcion del uruguay
# Processing Record 49 of Set 12 | saint anthony
# Processing Record 50 of Set 12 | katherine
# Processing Record 1 of Set 13 | puerto narino
# Processing Record 2 of Set 13 | marinhais
# Processing Record 3 of Set 13 | asau
# Processing Record 4 of Set 13 | yichang
# Processing Record 5 of Set 13 | savannah bight
# Processing Record 6 of Set 13 | yuancheng
# Processing Record 7 of Set 13 | kawalu
# Processing Record 8 of Set 13 | trairi
# Processing Record 9 of Set 13 | quatre cocos
# Processing Record 10 of Set 13 | saint-leu
# Processing Record 11 of Set 13 | itirapina
# Processing Record 12 of Set 13 | birjand
# Processing Record 13 of Set 13 | ouadda
# Processing Record 14 of Set 13 | along
# Processing Record 15 of Set 13 | aloleng
# Processing Record 16 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 13 | wadersloh
# Processing Record 18 of Set 13 | verkh-usugli
# Processing Record 19 of Set 13 | itarema
# Processing Record 20 of Set 13 | bosilegrad
# Processing Record 21 of Set 13 | mankapur
# Processing Record 22 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 13 | jacareacanga
# Processing Record 24 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 13 | mao
# Processing Record 26 of Set 13 | edd
# Processing Record 27 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 13 | kallithea
# Processing Record 29 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 30 of Set 13 | kudahuvadhoo
# Processing Record 31 of Set 13 | waipawa
# Processing Record 32 of Set 13 | kreminna
# Processing Record 33 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 34 of Set 13 | iracoubo
# Processing Record 35 of Set 13 | olinda
# Processing Record 36 of Set 13 | paramonga
# Processing Record 37 of Set 13 | gualeguay
# Processing Record 38 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 39 of Set 13 | sehithwa
# Processing Record 40 of Set 13 | maple creek
# Processing Record 41 of Set 13 | newport
# Processing Record 42 of Set 13 | alekseyevsk
# Processing Record 43 of Set 13 | huron
# Processing Record 44 of Set 13 | trat
# Processing Record 45 of Set 13 | elliot lake
# Processing Record 46 of Set 13 | sabha
# Processing Record 47 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 48 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 13 | luganville
# Processing Record 50 of Set 13 | faya
# Processing Record 1 of Set 14 | shaoyang
# Processing Record 2 of Set 14 | muisne
# Processing Record 3 of Set 14 | taoudenni
# Processing Record 4 of Set 14 | kangaba
# Processing Record 5 of Set 14 | cam ranh
# Processing Record 6 of Set 14 | parkes
# Processing Record 7 of Set 14 | sorong
# Processing Record 8 of Set 14 | phan thiet
# Processing Record 9 of Set 14 | paamiut
# Processing Record 10 of Set 14 | sanhsia
# City not found. Skipping...
# Processing Record 11 of Set 14 | tel aviv-yafo
# Processing Record 12 of Set 14 | yoichi
# Processing Record 13 of Set 14 | omboue
# Processing Record 14 of Set 14 | santa monica
# Processing Record 15 of Set 14 | port blair
# Processing Record 16 of Set 14 | herat
# Processing Record 17 of Set 14 | taseyevo
# Processing Record 18 of Set 14 | kiruna
# Processing Record 19 of Set 14 | sechura
# Processing Record 20 of Set 14 | aykhal
# Processing Record 21 of Set 14 | orlik
# Processing Record 22 of Set 14 | alugan
# Processing Record 23 of Set 14 | chapleau
# Processing Record 24 of Set 14 | novyy urengoy
# Processing Record 25 of Set 14 | brae
# Processing Record 26 of Set 14 | mayor pablo lagerenza
# Processing Record 27 of Set 14 | perigueux
# Processing Record 28 of Set 14 | bakchar
# Processing Record 29 of Set 14 | alyangula
# Processing Record 30 of Set 14 | moyale
# Processing Record 31 of Set 14 | vila
# Processing Record 32 of Set 14 | belaya gora
# Processing Record 33 of Set 14 | port-cartier
# Processing Record 34 of Set 14 | areka
# Processing Record 35 of Set 14 | arlit
# Processing Record 36 of Set 14 | sete
# Processing Record 37 of Set 14 | abu dhabi
# Processing Record 38 of Set 14 | springfield
# Processing Record 39 of Set 14 | bairiki
# Processing Record 40 of Set 14 | nikel
# Processing Record 41 of Set 14 | tortoli
# Processing Record 42 of Set 14 | cockburn town
# Processing Record 43 of Set 14 | yinchuan
# Processing Record 44 of Set 14 | chisinau
# Processing Record 45 of Set 14 | chipinge
# Processing Record 46 of Set 14 | sunrise manor
# Processing Record 47 of Set 14 | raisio
# Processing Record 48 of Set 14 | ormond beach
# Processing Record 49 of Set 14 | san german
# Processing Record 50 of Set 14 | moissac
# Processing Record 1 of Set 15 | paramithia
# City not found. Skipping...
# Processing Record 2 of Set 15 | kindu
# Processing Record 3 of Set 15 | kyshtovka
# Processing Record 4 of Set 15 | lagunas
# Processing Record 5 of Set 15 | teshie
# Processing Record 6 of Set 15 | beyla
# Processing Record 7 of Set 15 | linping
# Processing Record 8 of Set 15 | straumen
# Processing Record 9 of Set 15 | kulhudhuffushi
# Processing Record 10 of Set 15 | coihaique
# Processing Record 11 of Set 15 | alihe
# Processing Record 12 of Set 15 | teya
# Processing Record 13 of Set 15 | zhigansk
# Processing Record 14 of Set 15 | lewiston
# Processing Record 15 of Set 15 | krasnoselkup
# Processing Record 16 of Set 15 | kijang
# Processing Record 17 of Set 15 | concarneau
# Processing Record 18 of Set 15 | tomatlan
# Processing Record 19 of Set 15 | itacarambi
# Processing Record 20 of Set 15 | luanda
# Processing Record 21 of Set 15 | gari
# Processing Record 22 of Set 15 | saint-pierre
# Processing Record 23 of Set 15 | yokadouma
# Processing Record 24 of Set 15 | raudeberg
# Processing Record 25 of Set 15 | bobonong
# City not found. Skipping...
# Processing Record 26 of Set 15 | wajir
# Processing Record 27 of Set 15 | iskateley
# Processing Record 28 of Set 15 | lesnoy
# Processing Record 29 of Set 15 | port macquarie
# Processing Record 30 of Set 15 | kathmandu
# Processing Record 31 of Set 15 | hadrut
# Processing Record 32 of Set 15 | piacabucu
# Processing Record 33 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 34 of Set 15 | marivan
# Processing Record 35 of Set 15 | monrovia
# Processing Record 36 of Set 15 | mastic
# Processing Record 37 of Set 15 | deputatskiy
# Processing Record 38 of Set 15 | sakakah
# Processing Record 39 of Set 15 | wanaka
# Processing Record 40 of Set 15 | labuhan
# Processing Record 41 of Set 15 | tevaitoa
# Processing Record 42 of Set 15 | baoding
# Processing Record 43 of Set 15 | tulagi
# Processing Record 44 of Set 15 | awjilah
# Processing Record 45 of Set 15 | bengbu
# Processing Record 46 of Set 15 | kolondieba
# Processing Record 47 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 15 | beysehir
# Processing Record 50 of Set 15 | ust-tsilma
# Processing Record 1 of Set 16 | kachug
# Processing Record 2 of Set 16 | macusani
# Processing Record 3 of Set 16 | strathroy
# Processing Record 4 of Set 16 | buraydah
# Processing Record 5 of Set 16 | jujuy
# City not found. Skipping...
# Processing Record 6 of Set 16 | normandin
# Processing Record 7 of Set 16 | ostrovnoy
# Processing Record 8 of Set 16 | yumen
# Processing Record 9 of Set 16 | seddon
# Processing Record 10 of Set 16 | melnikovo
# Processing Record 11 of Set 16 | luangwa
# Processing Record 12 of Set 16 | caravelas
# Processing Record 13 of Set 16 | manzhouli
# Processing Record 14 of Set 16 | cacu
# Processing Record 15 of Set 16 | gusau
# Processing Record 16 of Set 16 | malolos
# Processing Record 17 of Set 16 | tianpeng
# Processing Record 18 of Set 16 | promyshlennovskiy
# Processing Record 19 of Set 16 | lazi
# Processing Record 20 of Set 16 | camacha
# Processing Record 21 of Set 16 | burkhala
# City not found. Skipping...
# Processing Record 22 of Set 16 | great yarmouth
# Processing Record 23 of Set 16 | muana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dunedin -45.8742  170.5036     53.80        84         100
# 1           Albany  42.6001  -73.9662     38.89        92         100
# 2          Rikitea -23.1203 -134.9692     77.61        76          89
# 3         Khatanga  71.9667  102.5000    -25.10        98          21
# 4           Tadine -21.5500  167.8833     78.03        86          92
# 5  Plettenberg Bay -34.0527   23.3716     64.36        70          31
# 6     Punta Arenas -53.1500  -70.9167     57.31        51          40
# 7           Castro -24.7911  -50.0119     82.51        42          80
# 8         Goderich  43.7501  -81.7165     36.91        93          97
# 9          Mataura -46.1927  168.8643     54.48        75         100
#
#    Wind Speed Country                 Date Current Description
# 0        5.50      NZ  2021-12-29 16:47:40     overcast clouds
# 1        1.86      US  2021-12-29 16:48:17     overcast clouds
# 2        6.82      PF  2021-12-29 16:48:17     overcast clouds
# 3        3.65      RU  2021-12-29 16:48:18          few clouds
# 4        8.70      NC  2021-12-29 16:48:18     overcast clouds
# 5        7.85      ZA  2021-12-29 16:48:18    scattered clouds
# 6       28.77      CL  2021-12-29 16:45:49    scattered clouds
# 7        3.20      BR  2021-12-29 16:48:19       broken clouds
# 8        4.61      CA  2021-12-29 16:48:19     overcast clouds
# 9        3.11      NZ  2021-12-29 16:48:19     overcast clouds

# %%
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Dunedin      NZ -45.8742  170.5036     53.80        84         100
# 1    Albany      US  42.6001  -73.9662     38.89        92         100
# 2   Rikitea      PF -23.1203 -134.9692     77.61        76          89
# 3  Khatanga      RU  71.9667  102.5000    -25.10        98          21
# 4    Tadine      NC -21.5500  167.8833     78.03        86          92
#
#    Wind Speed Current Description
# 0        5.50     overcast clouds
# 1        1.86     overcast clouds
# 2        6.82     overcast clouds
# 3        3.65          few clouds
# 4        8.70     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
