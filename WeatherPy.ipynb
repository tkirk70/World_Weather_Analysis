# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# Does zipping require lists of the same length?  Zip output is a tuple.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# You can only unzip a zipped tuple once before it is removed from the computer's memory.
# Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# 6.1.5 Generate Random World Cities

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 596

# %%
# Commit code as per OSU Module 6.1.5

# %%
# 6.2.6

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lucapa
# Processing Record 2 of Set 1 | port lincoln
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | victoria
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | sao felix do xingu
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | turukhansk
# Processing Record 10 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | muravlenko
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | beeville
# Processing Record 17 of Set 1 | kavaratti
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | valer
# Processing Record 21 of Set 1 | naze
# Processing Record 22 of Set 1 | chingirlau
# ...

# %%
# 6.2.7 Create a DataFrame of City Weather Data

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Lucapa  -8.4192   20.7447     66.25        98          95
# 1        Port Lincoln -34.7333  135.8667     58.21        85           4
# 2          Georgetown   5.4112  100.3354     78.89        91          20
# 3            Victoria  22.2855  114.1577     68.38        87          39
# 4               Vaini -21.2000 -175.2000     78.96        94          40
# 5  Sao Felix Do Xingu  -6.6447  -51.9950     85.44        67         100
# 6         Port Alfred -33.5906   26.8910     69.62        90          94
# 7        Punta Arenas -53.1500  -70.9167     64.51        45          40
# 8          Turukhansk  65.8167   87.9833      3.38        93         100
# 9              Atuona  -9.8000 -139.0333     78.75        79          64
#
#    Wind Speed Country                 Date
# 0        3.60      AO  2021-12-22 17:35:08
# 1       12.93      AU  2021-12-22 17:35:09
# ...

# %%
city_data_df.tail(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 544      Bacabal  -4.2917  -44.7917     96.42        35          83
# 545  Mozarlandia -14.7447  -50.5706     82.78        79          97
# 546   Shestakovo  56.4915  103.9600    -29.90        99           6
# 547  Grand-Santi   4.2500  -54.3833     75.15        98         100
# 548         Sola -13.8833  167.5500     82.26        70          87
# 549        Demba  -5.5100   22.2667     70.61        99         100
# 550  Chiang Kham  19.5233  100.3000     60.06        77           5
# 551      Mbarara  -0.6080   30.6500     64.83        89          96
# 552    Ascension  30.2169  -90.9001     63.10        53           1
# 553   Marienburg  54.0359   19.0266     30.11        86          99
#
#      Wind Speed Country                 Date
# 544        5.99      BR  2021-12-22 17:46:23
# 545        7.07      BR  2021-12-22 17:49:16
# 546        1.54      RU  2021-12-22 17:49:16
# ...

# %%
city_data_df.head(50)
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                  Lucapa  -8.4192   20.7447     66.25        98          95
# 1            Port Lincoln -34.7333  135.8667     58.21        85           4
# 2              Georgetown   5.4112  100.3354     78.89        91          20
# 3                Victoria  22.2855  114.1577     68.38        87          39
# 4                   Vaini -21.2000 -175.2000     78.96        94          40
# 5      Sao Felix Do Xingu  -6.6447  -51.9950     85.44        67         100
# 6             Port Alfred -33.5906   26.8910     69.62        90          94
# 7            Punta Arenas -53.1500  -70.9167     64.51        45          40
# 8              Turukhansk  65.8167   87.9833      3.38        93         100
# 9                  Atuona  -9.8000 -139.0333     78.75        79          64
# 10             Muravlenko  63.7898   74.5230     21.81        91         100
# ...

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0        Lucapa      AO  2021-12-22 17:35:08  -8.4192   20.7447     66.25
# 1  Port Lincoln      AU  2021-12-22 17:35:09 -34.7333  135.8667     58.21
# 2    Georgetown      MY  2021-12-22 17:35:09   5.4112  100.3354     78.89
# 3      Victoria      HK  2021-12-22 17:34:03  22.2855  114.1577     68.38
# 4         Vaini      TO  2021-12-22 17:35:10 -21.2000 -175.2000     78.96
#
#    Humidity  Cloudiness  Wind Speed
# 0        98          95        3.60
# 1        85           4       12.93
# 2        91          20        1.99
# 3        87          39        3.00
# 4        94          40        5.75

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 6.3.1 Plot Latitude vs. Temperature

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1640195359.2664695

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# 6.3.2 Plot Latitude vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# 6.3.3 Plot Latitude vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# 6.3.4 Plot Latitude vs. Wind Speed

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Commit code and push to GitHub.

# %%
# Playing around.  Do some coordinates not produce cites?
# Is weather data available for all cites?
# If city is skipped, is it because it doesn't exist in the db or couldn't be contacted at that moment?
coordinates[46]
# Out:
# (78.96705367181244, 87.01541020002367)

# %%
possible_city = citipy.nearest_city(5.83127281631063, -140.32801876579364).city_name
possible_city
# Out:
# 'atuona'

# %%
atuona_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key  + "&q=atuona"
requests.get(atuona_url).json()
# Out:
# {'coord': {'lon': -139.0333, 'lat': -9.8},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 78.82,
#   'feels_like': 78.82,
#   'temp_min': 78.82,
#   'temp_max': 78.82,
#   'pressure': 1014,
#   'humidity': 78,
#   'sea_level': 1014,
#   'grnd_level': 1006},
#  'visibility': 10000,
#  'wind': {'speed': 21.45, 'deg': 81, 'gust': 23.53},
#  'clouds': {'all': 74},
#  'dt': 1640195360,
#  'sys': {'country': 'PF', 'sunrise': 1640184843, 'sunset': 1640230546},
#  'timezone': -34200,
#  'id': 4020109,
#  'name': 'Atuona',
#  'cod': 200}

# %%
possible_city = citipy.nearest_city(35.0, -150.32801876579364).city_name
possible_city
# Out:
# 'kahului'

# %%
kahului_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key  + "&q=kahului"
requests.get(kahului_url).json()
# Out:
# {'coord': {'lon': -156.47, 'lat': 20.8947},
#  'weather': [{'id': 502,
#    'main': 'Rain',
#    'description': 'heavy intensity rain',
#    'icon': '10d'},
#   {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 67.64,
#   'feels_like': 68.38,
#   'temp_min': 66.97,
#   'temp_max': 69.06,
#   'pressure': 1015,
#   'humidity': 91},
#  'visibility': 9656,
#  'wind': {'speed': 8.05, 'deg': 40},
#  'rain': {'1h': 7.11},
#  'clouds': {'all': 90},
#  'dt': 1640194775,
#  'sys': {'type': 1,
#   'id': 7879,
#   'country': 'US',
#   'sunrise': 1640192332,
#   'sunset': 1640231430},
#  'timezone': -36000,
#  'id': 5847411,
#  'name': 'Kahului',
#  'cod': 200}

# %%
coordinates[12]
# Out:
# (32.583039641694015, -50.10275266294653)

# %%
possible_city = citipy.nearest_city(64.605822759272, 144.51812085914827).city_name
possible_city
# Out:
# 'artyk'

# %%
artyk_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key  + "&q=artyk"
requests.get(artyk_url).json()
# Out:
# {'cod': '404', 'message': 'city not found'}

# %%
# 6.4.1 Use Linear Regression to Find the Relationship Between Variables

# %%
# 6.4.2 Find the Correlation Between Latitude and Maximum Temperature

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
city_data_df.head()
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0        Lucapa      AO  2021-12-22 17:35:08  -8.4192   20.7447     66.25
# 1  Port Lincoln      AU  2021-12-22 17:35:09 -34.7333  135.8667     58.21
# 2    Georgetown      MY  2021-12-22 17:35:09   5.4112  100.3354     78.89
# 3      Victoria      HK  2021-12-22 17:34:03  22.2855  114.1577     68.38
# 4         Vaini      TO  2021-12-22 17:35:10 -21.2000 -175.2000     78.96
#
#    Humidity  Cloudiness  Wind Speed
# 0        98          95        3.60
# 1        85           4       12.93
# 2        91          20        1.99
# 3        87          39        3.00
# 4        94          40        5.75

# %%
index13 = city_data_df.loc[13]

# %%
index13
# Out:
# City                       Albany
# Country                        US
# Date          2021-12-22 17:34:05
# Lat                       42.6001
# Lng                      -73.9662
# Max Temp                    41.95
# Humidity                       69
# Cloudiness                     45
# Wind Speed                   1.99
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 549    False
# 550     True
# 551    False
# 552     True
# 553     True
# Name: Lat, Length: 554, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 2     Georgetown      MY  2021-12-22 17:35:09   5.4112  100.3354     78.89
# 3       Victoria      HK  2021-12-22 17:34:03  22.2855  114.1577     68.38
# 8     Turukhansk      RU  2021-12-22 17:35:11  65.8167   87.9833      3.38
# 10    Muravlenko      RU  2021-12-22 17:35:12  63.7898   74.5230     21.81
# 11  Saint George      US  2021-12-22 17:30:48  37.1041 -113.5841     55.54
#
#     Humidity  Cloudiness  Wind Speed
# 2         91          20        1.99
# 3         87          39        3.00
# 8         93         100       18.68
# 10        91         100       22.68
# 11        75           1        0.00

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(5,-30))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=-1.3641374362705945, intercept=94.54385997147713, rvalue=-0.8475268605635653, pvalue=1.0041041868393401e-102, stderr=0.044653567902575825, intercept_stderr=1.9330979494046312)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-30, 50))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.4274418500251412, intercept=84.03572539845655, rvalue=0.5254815552679253, pvalue=1.3526575044589825e-14, stderr=0.051020026793264, intercept_stderr=1.2136606163515424)

# %%
# 6.4.3 Find the Correlation Between Latitude and Percent Humidity

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.4635346838671726, intercept=53.55811851445935, rvalue=0.3988874238567901, pvalue=1.7385371477332746e-15, stderr=0.05570069818320194, intercept_stderr=2.411339350828061)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-55,22))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.1916528623796524, intercept=77.1117473630663, rvalue=0.13612217385668338, pvalue=0.06394309416343524, stderr=0.10282914002208655, intercept_stderr=2.44609196235431)

# %%
# 6.4.4 Find the Correlation Between Latitude and Percent Cloudiness

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Cloudiness', 'Cloudiness',(50,50))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.4544883190080739, intercept=41.63861499188785, rvalue=0.2320213266761992, pvalue=6.881595568325786e-06, stderr=0.09959509955940495, intercept_stderr=4.311572216336377)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Cloudiness', 'Cloudiness',(-55,56))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=1.029598843191732, intercept=81.91069841961499, rvalue=0.38511695529629986, pvalue=5.708216178556056e-08, stderr=0.1818888078856326, intercept_stderr=4.3267574825160455)

# %%
# 6.4.5 Find the Correlation Between Latitude and Wind Speed

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(0,29))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.06106179013487429, intercept=5.045933215211631, rvalue=0.20168997772079178, pvalue=9.778105927942145e-05, stderr=0.015499820970613538, intercept_stderr=0.6710028681202772)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-55,20))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=-0.10934203079667057, intercept=5.97197731695295, rvalue=-0.2815298254359489, pvalue=9.913350582356043e-05, stderr=0.027474041147908843, intercept_stderr=0.6535504547724189)

# %%
# 6.5.1 Set Up Google Maps and Places API
