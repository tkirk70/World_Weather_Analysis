# %%
# Import the random module.
import random

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Turn zipped tuples into a list of coordinates.
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | balkhash
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | klaksvik
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | port lincoln
# Processing Record 9 of Set 1 | deputatskiy
# Processing Record 10 of Set 1 | tabou
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | novovasylivka
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | puerto leguizamo
# Processing Record 16 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 1 | jiuquan
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | buala
# Processing Record 20 of Set 1 | lasa
# Processing Record 21 of Set 1 | saint-ambroise
# Processing Record 22 of Set 1 | muros
# Processing Record 23 of Set 1 | thompson
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | mehamn
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | salinopolis
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | sorland
# Processing Record 32 of Set 1 | viedma
# Processing Record 33 of Set 1 | sao filipe
# Processing Record 34 of Set 1 | igarka
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | jalu
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 1 | banda aceh
# Processing Record 40 of Set 1 | araouane
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | cherskiy
# Processing Record 44 of Set 1 | vila franca do campo
# Processing Record 45 of Set 1 | zachagansk
# City not found. Skipping...
# Processing Record 46 of Set 1 | biloela
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | gorontalo
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | mackenzie
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | richards bay
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | leshukonskoye
# Processing Record 8 of Set 2 | vuktyl
# Processing Record 9 of Set 2 | gotsu
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | kefamenanu
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | nome
# Processing Record 15 of Set 2 | longyearbyen
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | chapais
# Processing Record 18 of Set 2 | lorengau
# Processing Record 19 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | mondeville
# Processing Record 22 of Set 2 | rio cuarto
# Processing Record 23 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 2 | morondava
# Processing Record 25 of Set 2 | tam ky
# Processing Record 26 of Set 2 | asau
# Processing Record 27 of Set 2 | grand gaube
# Processing Record 28 of Set 2 | hualmay
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | campo de criptana
# Processing Record 33 of Set 2 | kailua
# Processing Record 34 of Set 2 | karchaghbyur
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 | locri
# Processing Record 37 of Set 2 | westport
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | kahului
# Processing Record 40 of Set 2 | penalva
# Processing Record 41 of Set 2 | sabaudia
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | lompoc
# Processing Record 44 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 2 | mandal
# Processing Record 46 of Set 2 | narasannapeta
# Processing Record 47 of Set 2 | montalban
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | del rio
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | laguna
# Processing Record 2 of Set 3 | pontian kecil
# Processing Record 3 of Set 3 | kongoussi
# Processing Record 4 of Set 3 | tipperary
# Processing Record 5 of Set 3 | khani
# Processing Record 6 of Set 3 | dongying
# Processing Record 7 of Set 3 | taywarah
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | albany
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | hamilton
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | batouri
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | esperance
# Processing Record 17 of Set 3 | dudhani
# Processing Record 18 of Set 3 | umm kaddadah
# Processing Record 19 of Set 3 | nabire
# Processing Record 20 of Set 3 | berlevag
# Processing Record 21 of Set 3 | yumen
# Processing Record 22 of Set 3 | kaseda
# Processing Record 23 of Set 3 | gurupa
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | fortuna
# Processing Record 26 of Set 3 | hofn
# Processing Record 27 of Set 3 | naze
# Processing Record 28 of Set 3 | san policarpo
# Processing Record 29 of Set 3 | savonlinna
# Processing Record 30 of Set 3 | hovd
# Processing Record 31 of Set 3 | havelock
# Processing Record 32 of Set 3 | kronshtadt
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | nimbahera
# Processing Record 35 of Set 3 | ilulissat
# Processing Record 36 of Set 3 | vostok
# Processing Record 37 of Set 3 | airai
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | cape town
# Processing Record 40 of Set 3 | nainpur
# Processing Record 41 of Set 3 | meadow lake
# Processing Record 42 of Set 3 | ust-omchug
# Processing Record 43 of Set 3 | seydi
# Processing Record 44 of Set 3 | pevek
# Processing Record 45 of Set 3 | jablah
# Processing Record 46 of Set 3 | mae hong son
# Processing Record 47 of Set 3 | souillac
# Processing Record 48 of Set 3 | tungor
# Processing Record 49 of Set 3 | san patricio
# Processing Record 50 of Set 3 | oistins
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | vila velha
# Processing Record 4 of Set 4 | panjab
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | saint-pierre
# Processing Record 7 of Set 4 | majene
# Processing Record 8 of Set 4 | srinagar
# Processing Record 9 of Set 4 | belaya gora
# Processing Record 10 of Set 4 | boa vista
# Processing Record 11 of Set 4 | brosteni
# Processing Record 12 of Set 4 | kloulklubed
# Processing Record 13 of Set 4 | zhezkazgan
# Processing Record 14 of Set 4 | gornopravdinsk
# Processing Record 15 of Set 4 | kalanchak
# Processing Record 16 of Set 4 | itigi
# Processing Record 17 of Set 4 | provost
# Processing Record 18 of Set 4 | morros
# Processing Record 19 of Set 4 | lafia
# Processing Record 20 of Set 4 | neapolis
# Processing Record 21 of Set 4 | kasama
# Processing Record 22 of Set 4 | hay river
# Processing Record 23 of Set 4 | bilma
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | dunn
# Processing Record 26 of Set 4 | ocala
# Processing Record 27 of Set 4 | lalganj
# Processing Record 28 of Set 4 | tiksi
# Processing Record 29 of Set 4 | sakaiminato
# Processing Record 30 of Set 4 | saint george
# Processing Record 31 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 4 | jatara
# Processing Record 33 of Set 4 | vanimo
# Processing Record 34 of Set 4 | norman wells
# Processing Record 35 of Set 4 | syamzha
# Processing Record 36 of Set 4 | caravelas
# Processing Record 37 of Set 4 | liepaja
# Processing Record 38 of Set 4 | ponta do sol
# Processing Record 39 of Set 4 | marzuq
# Processing Record 40 of Set 4 | otukpo
# Processing Record 41 of Set 4 | cairns
# Processing Record 42 of Set 4 | banjar
# Processing Record 43 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 44 of Set 4 | luderitz
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | bambous virieux
# Processing Record 47 of Set 4 | luena
# Processing Record 48 of Set 4 | blythe
# Processing Record 49 of Set 4 | codrington
# Processing Record 50 of Set 4 | zyryanka
# Processing Record 1 of Set 5 | champerico
# Processing Record 2 of Set 5 | aviles
# Processing Record 3 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 5 | zhigansk
# Processing Record 5 of Set 5 | talnakh
# Processing Record 6 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 7 of Set 5 | lata
# Processing Record 8 of Set 5 | keflavik
# Processing Record 9 of Set 5 | qui nhon
# Processing Record 10 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 5 | olafsvik
# Processing Record 12 of Set 5 | port moresby
# Processing Record 13 of Set 5 | krasnoselkup
# Processing Record 14 of Set 5 | acuitzio
# Processing Record 15 of Set 5 | dingle
# Processing Record 16 of Set 5 | praia
# Processing Record 17 of Set 5 | kurilsk
# Processing Record 18 of Set 5 | cabinda
# Processing Record 19 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 5 | machinga
# Processing Record 21 of Set 5 | dondo
# Processing Record 22 of Set 5 | san juan
# Processing Record 23 of Set 5 | port macquarie
# Processing Record 24 of Set 5 | san quintin
# Processing Record 25 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | kingsville
# Processing Record 27 of Set 5 | odweyne
# Processing Record 28 of Set 5 | anadyr
# Processing Record 29 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 5 | kavaratti
# Processing Record 31 of Set 5 | piacabucu
# Processing Record 32 of Set 5 | ilula
# Processing Record 33 of Set 5 | la ronge
# Processing Record 34 of Set 5 | geraldton
# Processing Record 35 of Set 5 | oblivskaya
# Processing Record 36 of Set 5 | beidao
# Processing Record 37 of Set 5 | wlodawa
# Processing Record 38 of Set 5 | batticaloa
# Processing Record 39 of Set 5 | southbridge
# Processing Record 40 of Set 5 | sobolevo
# Processing Record 41 of Set 5 | ende
# Processing Record 42 of Set 5 | flinders
# Processing Record 43 of Set 5 | olga
# Processing Record 44 of Set 5 | atar
# Processing Record 45 of Set 5 | oksfjord
# Processing Record 46 of Set 5 | marathopolis
# City not found. Skipping...
# Processing Record 47 of Set 5 | mount gambier
# Processing Record 48 of Set 5 | saint-leu
# Processing Record 49 of Set 5 | hoi an
# Processing Record 50 of Set 5 | la malbaie
# Processing Record 1 of Set 6 | ampanihy
# Processing Record 2 of Set 6 | tairua
# Processing Record 3 of Set 6 | cayenne
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | manaus
# Processing Record 6 of Set 6 | phonhong
# Processing Record 7 of Set 6 | siswa bazar
# Processing Record 8 of Set 6 | tura
# Processing Record 9 of Set 6 | eureka
# Processing Record 10 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 11 of Set 6 | maceio
# Processing Record 12 of Set 6 | bundaberg
# Processing Record 13 of Set 6 | tres arroyos
# Processing Record 14 of Set 6 | iqaluit
# Processing Record 15 of Set 6 | margate
# Processing Record 16 of Set 6 | bangangte
# Processing Record 17 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 6 | uzhur-4
# City not found. Skipping...
# Processing Record 19 of Set 6 | pundaguitan
# Processing Record 20 of Set 6 | provideniya
# Processing Record 21 of Set 6 | gamboma
# Processing Record 22 of Set 6 | north platte
# Processing Record 23 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 25 of Set 6 | dibombari
# Processing Record 26 of Set 6 | chino valley
# Processing Record 27 of Set 6 | vizinga
# Processing Record 28 of Set 6 | khandbari
# Processing Record 29 of Set 6 | grindavik
# Processing Record 30 of Set 6 | faya
# Processing Record 31 of Set 6 | srednekolymsk
# Processing Record 32 of Set 6 | port-gentil
# Processing Record 33 of Set 6 | chimbote
# Processing Record 34 of Set 6 | awbari
# Processing Record 35 of Set 6 | harper
# Processing Record 36 of Set 6 | cabo san lucas
# Processing Record 37 of Set 6 | saint-philippe
# Processing Record 38 of Set 6 | balakhta
# Processing Record 39 of Set 6 | verkhniy landekh
# Processing Record 40 of Set 6 | victor harbor
# Processing Record 41 of Set 6 | namibe
# Processing Record 42 of Set 6 | labuhan
# Processing Record 43 of Set 6 | cidreira
# Processing Record 44 of Set 6 | lagoa
# Processing Record 45 of Set 6 | bandundu
# Processing Record 46 of Set 6 | taksimo
# Processing Record 47 of Set 6 | puerto penasco
# Processing Record 48 of Set 6 | bonfim
# Processing Record 49 of Set 6 | hefei
# Processing Record 50 of Set 6 | lomas de sargentillo
# Processing Record 1 of Set 7 | shingu
# Processing Record 2 of Set 7 | korgen
# Processing Record 3 of Set 7 | ketchikan
# Processing Record 4 of Set 7 | suoyarvi
# Processing Record 5 of Set 7 | hukuntsi
# Processing Record 6 of Set 7 | dikson
# Processing Record 7 of Set 7 | jumla
# Processing Record 8 of Set 7 | stafford
# Processing Record 9 of Set 7 | teya
# Processing Record 10 of Set 7 | bubaque
# Processing Record 11 of Set 7 | baruun-urt
# Processing Record 12 of Set 7 | port said
# Processing Record 13 of Set 7 | port hardy
# Processing Record 14 of Set 7 | mayumba
# Processing Record 15 of Set 7 | mount isa
# Processing Record 16 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 7 | matagami
# Processing Record 18 of Set 7 | emerald
# Processing Record 19 of Set 7 | kruisfontein
# Processing Record 20 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 7 | port elizabeth
# Processing Record 22 of Set 7 | mizdah
# Processing Record 23 of Set 7 | noumea
# Processing Record 24 of Set 7 | wajima
# Processing Record 25 of Set 7 | vestmannaeyjar
# Processing Record 26 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 7 | bom jesus
# Processing Record 28 of Set 7 | half moon bay
# Processing Record 29 of Set 7 | castro verde
# Processing Record 30 of Set 7 | san luis
# Processing Record 31 of Set 7 | taoudenni
# Processing Record 32 of Set 7 | morena
# Processing Record 33 of Set 7 | sorgun
# Processing Record 34 of Set 7 | khatanga
# Processing Record 35 of Set 7 | coquimbo
# Processing Record 36 of Set 7 | trelew
# Processing Record 37 of Set 7 | torbay
# Processing Record 38 of Set 7 | marmaron
# City not found. Skipping...
# Processing Record 39 of Set 7 | poum
# Processing Record 40 of Set 7 | ciechocinek
# Processing Record 41 of Set 7 | summerville
# Processing Record 42 of Set 7 | leningradskiy
# Processing Record 43 of Set 7 | tessalit
# Processing Record 44 of Set 7 | vaitape
# Processing Record 45 of Set 7 | grande-riviere
# City not found. Skipping...
# Processing Record 46 of Set 7 | kununurra
# Processing Record 47 of Set 7 | burlatskoye
# Processing Record 48 of Set 7 | sept-iles
# Processing Record 49 of Set 7 | sinnamary
# Processing Record 50 of Set 7 | khandyga
# Processing Record 1 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 8 | san jeronimo
# Processing Record 3 of Set 8 | san matias
# Processing Record 4 of Set 8 | mapimi
# Processing Record 5 of Set 8 | srandakan
# Processing Record 6 of Set 8 | katsuura
# Processing Record 7 of Set 8 | saldanha
# Processing Record 8 of Set 8 | tucuman
# Processing Record 9 of Set 8 | fort nelson
# Processing Record 10 of Set 8 | palana
# Processing Record 11 of Set 8 | abonnema
# Processing Record 12 of Set 8 | acapulco
# Processing Record 13 of Set 8 | maldonado
# Processing Record 14 of Set 8 | garchitorena
# Processing Record 15 of Set 8 | arlit
# Processing Record 16 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 17 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 8 | sao joao da barra
# Processing Record 19 of Set 8 | sisimiut
# Processing Record 20 of Set 8 | meulaboh
# Processing Record 21 of Set 8 | chokurdakh
# Processing Record 22 of Set 8 | masvingo
# Processing Record 23 of Set 8 | solwezi
# Processing Record 24 of Set 8 | shelbyville
# Processing Record 25 of Set 8 | shaunavon
# Processing Record 26 of Set 8 | honiara
# Processing Record 27 of Set 8 | korla
# Processing Record 28 of Set 8 | hami
# Processing Record 29 of Set 8 | leh
# Processing Record 30 of Set 8 | apatity
# Processing Record 31 of Set 8 | sao jose da coroa grande
# Processing Record 32 of Set 8 | kemptville
# Processing Record 33 of Set 8 | coihaique
# Processing Record 34 of Set 8 | sena madureira
# Processing Record 35 of Set 8 | kavieng
# Processing Record 36 of Set 8 | gresham
# Processing Record 37 of Set 8 | neiafu
# Processing Record 38 of Set 8 | kapit
# Processing Record 39 of Set 8 | atikokan
# Processing Record 40 of Set 8 | karakol
# Processing Record 41 of Set 8 | rocha
# Processing Record 42 of Set 8 | banfora
# Processing Record 43 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 8 | okhotsk
# Processing Record 45 of Set 8 | ahipara
# Processing Record 46 of Set 8 | yaransk
# Processing Record 47 of Set 8 | hambantota
# Processing Record 48 of Set 8 | rio gallegos
# Processing Record 49 of Set 8 | senador jose porfirio
# Processing Record 50 of Set 8 | mayor pablo lagerenza
# Processing Record 1 of Set 9 | ambulu
# Processing Record 2 of Set 9 | tabas
# Processing Record 3 of Set 9 | road town
# Processing Record 4 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 9 | faanui
# Processing Record 6 of Set 9 | rio grande
# Processing Record 7 of Set 9 | eyl
# Processing Record 8 of Set 9 | prince george
# Processing Record 9 of Set 9 | behbahan
# Processing Record 10 of Set 9 | tripoli
# Processing Record 11 of Set 9 | gumushane
# City not found. Skipping...
# Processing Record 12 of Set 9 | princeton
# Processing Record 13 of Set 9 | krk
# Processing Record 14 of Set 9 | acarau
# Processing Record 15 of Set 9 | ellisras
# Processing Record 16 of Set 9 | guerrero negro
# Processing Record 17 of Set 9 | bac lieu
# Processing Record 18 of Set 9 | strezhevoy
# Processing Record 19 of Set 9 | yerbogachen
# Processing Record 20 of Set 9 | waipawa
# Processing Record 21 of Set 9 | erenhot
# Processing Record 22 of Set 9 | skjervoy
# Processing Record 23 of Set 9 | bowmore
# Processing Record 24 of Set 9 | college
# Processing Record 25 of Set 9 | sungaipenuh
# Processing Record 26 of Set 9 | marienburg
# Processing Record 27 of Set 9 | fredonia
# Processing Record 28 of Set 9 | goderich
# Processing Record 29 of Set 9 | liwale
# Processing Record 30 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 31 of Set 9 | beipiao
# Processing Record 32 of Set 9 | dicabisagan
# Processing Record 33 of Set 9 | marawi
# Processing Record 34 of Set 9 | lerwick
# Processing Record 35 of Set 9 | udaipura
# Processing Record 36 of Set 9 | hirara
# Processing Record 37 of Set 9 | havre-saint-pierre
# Processing Record 38 of Set 9 | chhaprauli
# Processing Record 39 of Set 9 | novy bydzov
# Processing Record 40 of Set 9 | mishan
# Processing Record 41 of Set 9 | axim
# Processing Record 42 of Set 9 | ahuimanu
# Processing Record 43 of Set 9 | florida
# Processing Record 44 of Set 9 | omachi
# Processing Record 45 of Set 9 | rockingham
# Processing Record 46 of Set 9 | farafangana
# Processing Record 47 of Set 9 | ashqelon
# Processing Record 48 of Set 9 | springfield
# Processing Record 49 of Set 9 | campbell river
# Processing Record 50 of Set 9 | rocky mountain house
# Processing Record 1 of Set 10 | karratha
# Processing Record 2 of Set 10 | springbok
# Processing Record 3 of Set 10 | sturgeon falls
# Processing Record 4 of Set 10 | sungai padi
# Processing Record 5 of Set 10 | ajdabiya
# Processing Record 6 of Set 10 | haines junction
# Processing Record 7 of Set 10 | moville
# Processing Record 8 of Set 10 | belyy yar
# Processing Record 9 of Set 10 | placido de castro
# Processing Record 10 of Set 10 | charters towers
# Processing Record 11 of Set 10 | teguise
# Processing Record 12 of Set 10 | bathsheba
# Processing Record 13 of Set 10 | rovaniemi
# Processing Record 14 of Set 10 | izhmorskiy
# Processing Record 15 of Set 10 | mukhen
# Processing Record 16 of Set 10 | perpignan
# Processing Record 17 of Set 10 | ranghulu
# Processing Record 18 of Set 10 | roma
# Processing Record 19 of Set 10 | basoko
# Processing Record 20 of Set 10 | cockburn town
# Processing Record 21 of Set 10 | tonj
# Processing Record 22 of Set 10 | le port
# Processing Record 23 of Set 10 | chernyshevskiy
# Processing Record 24 of Set 10 | palimbang
# Processing Record 25 of Set 10 | nouadhibou
# Processing Record 26 of Set 10 | bethel
# Processing Record 27 of Set 10 | gigmoto
# Processing Record 28 of Set 10 | saint-michel-des-saints
# Processing Record 29 of Set 10 | batsfjord
# Processing Record 30 of Set 10 | venado tuerto
# Processing Record 31 of Set 10 | phan thiet
# Processing Record 32 of Set 10 | urussu
# Processing Record 33 of Set 10 | iwanai
# Processing Record 34 of Set 10 | constitucion
# Processing Record 35 of Set 10 | chuchkovo
# Processing Record 36 of Set 10 | praia da vitoria
# Processing Record 37 of Set 10 | mahanoro
# Processing Record 38 of Set 10 | paamiut
# Processing Record 39 of Set 10 | beringovskiy
# Processing Record 40 of Set 10 | lavrentiya
# Processing Record 41 of Set 10 | tuatapere
# Processing Record 42 of Set 10 | severo-kurilsk
# Processing Record 43 of Set 10 | yermakovskoye
# Processing Record 44 of Set 10 | san cristobal
# Processing Record 45 of Set 10 | salym
# Processing Record 46 of Set 10 | sao raimundo nonato
# Processing Record 47 of Set 10 | bonavista
# Processing Record 48 of Set 10 | wattegama
# Processing Record 49 of Set 10 | grong
# Processing Record 50 of Set 10 | moerai
# Processing Record 1 of Set 11 | visconde do rio branco
# Processing Record 2 of Set 11 | acajutla
# Processing Record 3 of Set 11 | necochea
# Processing Record 4 of Set 11 | gladstone
# Processing Record 5 of Set 11 | gat
# Processing Record 6 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 11 | sao miguel do araguaia
# Processing Record 8 of Set 11 | darhan
# Processing Record 9 of Set 11 | mandiana
# Processing Record 10 of Set 11 | khasan
# Processing Record 11 of Set 11 | puerto el triunfo
# Processing Record 12 of Set 11 | el seibo
# Processing Record 13 of Set 11 | abu samrah
# Processing Record 14 of Set 11 | altamira
# Processing Record 15 of Set 11 | lebanon
# Processing Record 16 of Set 11 | mahon
# Processing Record 17 of Set 11 | pontianak
# Processing Record 18 of Set 11 | northam
# Processing Record 19 of Set 11 | honningsvag
# Processing Record 20 of Set 11 | kristinehamn
# Processing Record 21 of Set 11 | pitimbu
# Processing Record 22 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 11 | cap malheureux
# Processing Record 24 of Set 11 | vardo
# Processing Record 25 of Set 11 | khammam
# Processing Record 26 of Set 11 | timmins
# Processing Record 27 of Set 11 | rafai
# Processing Record 28 of Set 11 | racine
# Processing Record 29 of Set 11 | zawadzkie
# Processing Record 30 of Set 11 | selenginsk
# Processing Record 31 of Set 11 | jining
# Processing Record 32 of Set 11 | pisco
# Processing Record 33 of Set 11 | limbang
# Processing Record 34 of Set 11 | sibiti
# Processing Record 35 of Set 11 | kota belud
# Processing Record 36 of Set 11 | saint pete beach
# Processing Record 37 of Set 11 | bandarbeyla
# Processing Record 38 of Set 11 | golden
# Processing Record 39 of Set 11 | bud
# Processing Record 40 of Set 11 | khudumelapye
# Processing Record 41 of Set 11 | karimganj
# Processing Record 42 of Set 11 | aasiaat
# Processing Record 43 of Set 11 | opuwo
# Processing Record 44 of Set 11 | port hedland
# Processing Record 45 of Set 11 | teapa
# Processing Record 46 of Set 11 | kavali
# Processing Record 47 of Set 11 | sechura
# Processing Record 48 of Set 11 | masoko
# Processing Record 49 of Set 11 | aklavik
# Processing Record 50 of Set 11 | dunyapur
# Processing Record 1 of Set 12 | shakawe
# Processing Record 2 of Set 12 | palmer
# Processing Record 3 of Set 12 | slonim
# Processing Record 4 of Set 12 | paita
# Processing Record 5 of Set 12 | siparia
# Processing Record 6 of Set 12 | nhulunbuy
# Processing Record 7 of Set 12 | kinsale
# Processing Record 8 of Set 12 | te anau
# Processing Record 9 of Set 12 | okakarara
# Processing Record 10 of Set 12 | buinsk
# Processing Record 11 of Set 12 | dzialdowo
# Processing Record 12 of Set 12 | maningrida
# Processing Record 13 of Set 12 | akdagmadeni
# Processing Record 14 of Set 12 | mahwa
# Processing Record 15 of Set 12 | killini
# City not found. Skipping...
# Processing Record 16 of Set 12 | sao gabriel da cachoeira
# Processing Record 17 of Set 12 | muisne
# Processing Record 18 of Set 12 | the valley
# Processing Record 19 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 20 of Set 12 | salalah
# Processing Record 21 of Set 12 | kidal
# Processing Record 22 of Set 12 | mitsamiouli
# Processing Record 23 of Set 12 | key largo
# Processing Record 24 of Set 12 | karanja
# Processing Record 25 of Set 12 | quatre cocos
# Processing Record 26 of Set 12 | los algarrobos
# Processing Record 27 of Set 12 | ewa beach
# Processing Record 28 of Set 12 | marechal candido rondon
# Processing Record 29 of Set 12 | aldan
# Processing Record 30 of Set 12 | arroyo
# Processing Record 31 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 12 | vanavara
# Processing Record 33 of Set 12 | muyezerskiy
# Processing Record 34 of Set 12 | winona
# Processing Record 35 of Set 12 | okoneshnikovo
# Processing Record 36 of Set 12 | taltal
# Processing Record 37 of Set 12 | ust-tsilma
# Processing Record 38 of Set 12 | fukue
# Processing Record 39 of Set 12 | kaitangata
# Processing Record 40 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 12 | fairbanks
# Processing Record 42 of Set 12 | basco
# Processing Record 43 of Set 12 | novyy urgal
# Processing Record 44 of Set 12 | avera
# Processing Record 45 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 12 | petrov val
# Processing Record 47 of Set 12 | nuzvid
# Processing Record 48 of Set 12 | esfarayen
# Processing Record 49 of Set 12 | guasdualito
# Processing Record 50 of Set 12 | kirakira
# Processing Record 1 of Set 13 | great yarmouth
# Processing Record 2 of Set 13 | virginia beach
# Processing Record 3 of Set 13 | romans-sur-isere
# Processing Record 4 of Set 13 | depalpur
# Processing Record 5 of Set 13 | iacu
# Processing Record 6 of Set 13 | tarko-sale
# Processing Record 7 of Set 13 | mitu
# Processing Record 8 of Set 13 | alyangula
# Processing Record 9 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 10 of Set 13 | shieli
# Processing Record 11 of Set 13 | ojinaga
# Processing Record 12 of Set 13 | sarahan
# Processing Record 13 of Set 13 | mezen
# Processing Record 14 of Set 13 | raudeberg
# Processing Record 15 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 13 | tarakan
# Processing Record 17 of Set 13 | russkaya polyana
# Processing Record 18 of Set 13 | touros
# Processing Record 19 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 13 | siniscola
# Processing Record 21 of Set 13 | plettenberg bay
# Processing Record 22 of Set 13 | mangai
# Processing Record 23 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 24 of Set 13 | kutum
# Processing Record 25 of Set 13 | olyka
# Processing Record 26 of Set 13 | inhambane
# Processing Record 27 of Set 13 | moanda
# Processing Record 28 of Set 13 | pangnirtung
# Processing Record 29 of Set 13 | riyadh
# Processing Record 30 of Set 13 | alofi
# Processing Record 31 of Set 13 | urusha
# Processing Record 32 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 13 | nyaunglebin
# Processing Record 34 of Set 13 | san eugenio
# Processing Record 35 of Set 13 | dalbandin
# Processing Record 36 of Set 13 | general roca
# Processing Record 37 of Set 13 | yamada
# Processing Record 38 of Set 13 | fergus falls
# Processing Record 39 of Set 13 | murray bridge
# Processing Record 40 of Set 13 | nalut
# Processing Record 41 of Set 13 | usinsk
# Processing Record 42 of Set 13 | mamit
# Processing Record 43 of Set 13 | estevan
# Processing Record 44 of Set 13 | gloucester
# Processing Record 45 of Set 13 | bosaso
# Processing Record 46 of Set 13 | aquiraz
# Processing Record 47 of Set 13 | bilibino
# Processing Record 48 of Set 13 | la maddalena
# Processing Record 49 of Set 13 | isfana
# Processing Record 50 of Set 13 | omboue
# Processing Record 1 of Set 14 | rudbar
# Processing Record 2 of Set 14 | kuusamo
# Processing Record 3 of Set 14 | samarinda
# Processing Record 4 of Set 14 | mahuta
# Processing Record 5 of Set 14 | hayden
# Processing Record 6 of Set 14 | punta alta
# Processing Record 7 of Set 14 | ventspils
# Processing Record 8 of Set 14 | zunyi
# Processing Record 9 of Set 14 | nishihara
# Processing Record 10 of Set 14 | baculin
# Processing Record 11 of Set 14 | chapleau
# Processing Record 12 of Set 14 | matnog
# Processing Record 13 of Set 14 | biak
# Processing Record 14 of Set 14 | mackay
# Processing Record 15 of Set 14 | burtunay
# Processing Record 16 of Set 14 | baragua
# Processing Record 17 of Set 14 | mosquera
# Processing Record 18 of Set 14 | port blair
# Processing Record 19 of Set 14 | berasia
# Processing Record 20 of Set 14 | miyazu
# Processing Record 21 of Set 14 | yakeshi
# Processing Record 22 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 14 | qovlar
# Processing Record 24 of Set 14 | aguas formosas
# Processing Record 25 of Set 14 | portree
# Processing Record 26 of Set 14 | bereda
# Processing Record 27 of Set 14 | ukiah
# Processing Record 28 of Set 14 | lake city
# Processing Record 29 of Set 14 | kemijarvi
# Processing Record 30 of Set 14 | guarapari
# Processing Record 31 of Set 14 | kolobrzeg
# Processing Record 32 of Set 14 | ostersund
# Processing Record 33 of Set 14 | tiznit
# Processing Record 34 of Set 14 | playa vicente
# Processing Record 35 of Set 14 | esperantinopolis
# Processing Record 36 of Set 14 | zafra
# Processing Record 37 of Set 14 | husavik
# Processing Record 38 of Set 14 | khorramshahr
# Processing Record 39 of Set 14 | lubao
# Processing Record 40 of Set 14 | yar-sale
# Processing Record 41 of Set 14 | shimoda
# Processing Record 42 of Set 14 | tamandare
# Processing Record 43 of Set 14 | tupaciguara
# Processing Record 44 of Set 14 | asfi
# Processing Record 45 of Set 14 | wynyard
# Processing Record 46 of Set 14 | kudahuvadhoo
# Processing Record 47 of Set 14 | baykit
# Processing Record 48 of Set 14 | henties bay
# Processing Record 49 of Set 14 | pangoa
# Processing Record 50 of Set 14 | sao felix do xingu
# Processing Record 1 of Set 15 | bandar-e anzali
# Processing Record 2 of Set 15 | jales
# Processing Record 3 of Set 15 | sao miguel do guama
# Processing Record 4 of Set 15 | altoona
# Processing Record 5 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 15 | san vicente
# Processing Record 7 of Set 15 | worland
# Processing Record 8 of Set 15 | puerto escondido
# Processing Record 9 of Set 15 | kintampo
# Processing Record 10 of Set 15 | poduri
# Processing Record 11 of Set 15 | aksarka
# Processing Record 12 of Set 15 | kieta
# Processing Record 13 of Set 15 | kysyl-syr
# Processing Record 14 of Set 15 | gogrial
# Processing Record 15 of Set 15 | karonga
# Processing Record 16 of Set 15 | ust-kuyga
# Processing Record 17 of Set 15 | aiquile
# Processing Record 18 of Set 15 | yefimovskiy
# City not found. Skipping...
# Processing Record 19 of Set 15 | sioux city
# Processing Record 20 of Set 15 | mildura
# Processing Record 21 of Set 15 | burica
# City not found. Skipping...
# Processing Record 22 of Set 15 | ishigaki
# Processing Record 23 of Set 15 | spornoye
# Processing Record 24 of Set 15 | belmonte
# Processing Record 25 of Set 15 | kota kinabalu
# Processing Record 26 of Set 15 | mayo
# Processing Record 27 of Set 15 | santa maria
# Processing Record 28 of Set 15 | ponferrada
# Processing Record 29 of Set 15 | veraval
# Processing Record 30 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 15 | energeticheskiy
# Processing Record 32 of Set 15 | tigil
# Processing Record 33 of Set 15 | kankon
# Processing Record 34 of Set 15 | tsiroanomandidy
# Processing Record 35 of Set 15 | kwinana
# Processing Record 36 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 15 | puerto madryn
# Processing Record 38 of Set 15 | orbetello
# Processing Record 39 of Set 15 | zlobin
# Processing Record 40 of Set 15 | valparaiso
# Processing Record 41 of Set 15 | flin flon
# Processing Record 42 of Set 15 | susanville
# Processing Record 43 of Set 15 | bograd
# Processing Record 44 of Set 15 | alta
# Processing Record 45 of Set 15 | kudat
# Processing Record 46 of Set 15 | petauke
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Balkhash  46.8440   74.9804     22.75        83         100
# 1  Puerto Ayora  -0.7393  -90.3518     78.76        90          95
# 2      Klaksvik  62.2266   -6.5890     38.32        98         100
# 3       Rikitea -23.1203 -134.9692     77.86        73          12
# 4          Chuy -33.6971  -53.4616     78.44        52          17
# 5      Hermanus -34.4187   19.2345     63.90        76          19
# 6   Tuktoyaktuk  69.4541 -133.0374    -25.60        68          40
# 7  Port Lincoln -34.7333  135.8667     63.79        82           0
# 8   Deputatskiy  69.3000  139.9000    -35.07       100          98
# 9         Tabou   4.4230   -7.3528     80.13        82          93
#
#    Wind Speed Country                 Date Current Description
# 0        6.13      KZ  2021-12-29 19:44:09          light snow
# 1        4.00      EC  2021-12-29 19:44:09     overcast clouds
# 2       31.74      FO  2021-12-29 19:44:10     overcast clouds
# 3        3.76      PF  2021-12-29 19:44:10          few clouds
# 4       15.26      UY  2021-12-29 19:44:10          few clouds
# 5       12.77      ZA  2021-12-29 19:44:11          few clouds
# 6       10.36      CA  2021-12-29 19:44:11    scattered clouds
# 7        7.14      AU  2021-12-29 19:44:11           clear sky
# 8        0.38      RU  2021-12-29 19:44:12     overcast clouds
# 9        7.54      CI  2021-12-29 19:44:12     overcast clouds

# %%
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Balkhash      KZ  46.8440   74.9804     22.75        83         100
# 1  Puerto Ayora      EC  -0.7393  -90.3518     78.76        90          95
# 2      Klaksvik      FO  62.2266   -6.5890     38.32        98         100
# 3       Rikitea      PF -23.1203 -134.9692     77.86        73          12
# 4          Chuy      UY -33.6971  -53.4616     78.44        52          17
#
#    Wind Speed Current Description
# 0        6.13          light snow
# 1        4.00     overcast clouds
# 2       31.74     overcast clouds
# 3        3.76          few clouds
# 4       15.26          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
