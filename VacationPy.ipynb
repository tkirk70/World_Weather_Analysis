# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID          City Country                 Date      Lat       Lng  \
# 0        0        Lucapa      AO  2021-12-22 17:35:08  -8.4192   20.7447
# 1        1  Port Lincoln      AU  2021-12-22 17:35:09 -34.7333  135.8667
# 2        2    Georgetown      MY  2021-12-22 17:35:09   5.4112  100.3354
# 3        3      Victoria      HK  2021-12-22 17:34:03  22.2855  114.1577
# 4        4         Vaini      TO  2021-12-22 17:35:10 -21.2000 -175.2000
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     66.25        98          95        3.60
# 1     58.21        85           4       12.93
# 2     78.89        91          20        1.99
# 3     68.38        87          39        3.00
# 4     78.96        94          40        5.75

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# 6.5.2 Create Heat Maps

# %%
"""# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))"""
# Out:
# '# Get the maximum temperature.\nmax_temp = city_data_df["Max Temp"]\ntemps = []\nfor temp in max_temp:\n    temps.append(max(temp, 0))'

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.7)
# Assign the heatmap variable.
# Changed to list comprehension to disallow negative numbers here.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 19.0), zoom_level=1.7)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 19.0), zoom_level=1.7)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of wind speed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 19.0), zoom_level=1.7)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 6.5.3 Get Vacation Criteria

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID                City Country                 Date      Lat  \
# 2         2          Georgetown      MY  2021-12-22 17:35:09   5.4112
# 4         4               Vaini      TO  2021-12-22 17:35:10 -21.2000
# 5         5  Sao Felix Do Xingu      BR  2021-12-22 17:35:11  -6.6447
# 9         9              Atuona      PF  2021-12-22 17:35:12  -9.8000
# 15       15           Kavaratti      IN  2021-12-22 17:35:13  10.5669
# 21       21            Pimentel      PE  2021-12-22 17:35:14  -6.8367
# 24       24              Castro      BR  2021-12-22 17:35:15 -24.7911
# 25       25             Rikitea      PF  2021-12-22 17:34:19 -23.1203
# 29       29             Isangel      VU  2021-12-22 17:35:16 -19.5500
# 33       33              Avarua      CK  2021-12-22 17:35:18 -21.2078
#
#          Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 2   100.3354     78.89        91          20        1.99
# 4  -175.2000     78.96        94          40        5.75
# 5   -51.9950     85.44        67         100        3.91
# 9  -139.0333     78.75        79          64       20.94
# 15   72.6420     79.63        59          46        2.26
# 21  -79.9342     79.09        53           0        9.22
# 24  -50.0119     78.55        50          22       12.06
# 25 -134.9692     77.00        78          88       10.42
# 29  169.2667     78.40        84          10        4.23
# 33 -159.7750     77.05        83          75        8.05

# %%
preferred_cities_df.count()
# Out:
# City_ID       157
# City          157
# Country       155
# Date          157
# Lat           157
# Lng           157
# Max Temp      157
# Humidity      157
# Cloudiness    157
# Wind Speed    157
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                   City Country  Max Temp      Lat       Lng Hotel Name
# 2           Georgetown      MY     78.89   5.4112  100.3354
# 4                Vaini      TO     78.96 -21.2000 -175.2000
# 5   Sao Felix Do Xingu      BR     85.44  -6.6447  -51.9950
# 9               Atuona      PF     78.75  -9.8000 -139.0333
# 15           Kavaratti      IN     79.63  10.5669   72.6420
# 21            Pimentel      PE     79.09  -6.8367  -79.9342
# 24              Castro      BR     78.55 -24.7911  -50.0119
# 25             Rikitea      PF     77.00 -23.1203 -134.9692
# 29             Isangel      VU     78.40 -19.5500  169.2667
# 33              Avarua      CK     77.05 -21.2078 -159.7750

# %%
# 6.5.4 Map Vacation Criteria

# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

no_hotels = []

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]
    city = row["City"]
   

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print(f"Hotel not found near {city, lat, lng}... skipping.")
        no_hotels.append(city)
print(f"There were {len(no_hotels)} cities without hotels.\nThey included: {no_hotels}.")
# Out:
# Hotel not found near ('Mayor Pablo Lagerenza', -19.9309, -60.7718)... skipping.
# Hotel not found near ('Kayes', 14.0, -11.0)... skipping.
# Hotel not found near ('Gamba', -2.65, 10.0)... skipping.
# Hotel not found near ('Ndele', 8.4109, 20.6473)... skipping.
# Hotel not found near ('Tsogni', -2.7942, 10.0988)... skipping.
# Hotel not found near ('Boende', -0.2167, 20.8667)... skipping.
# Hotel not found near ('Aripuana', -9.1667, -60.6333)... skipping.
# Hotel not found near ('Gaoua', 10.2992, -3.2508)... skipping.
# Hotel not found near ('San Francisco Del Mar', 16.2333, -94.65)... skipping.
# Hotel not found near ('Amapa', 1.0, -52.0)... skipping.
# There were 10 cities without hotels.
# They included: ['Mayor Pablo Lagerenza', 'Kayes', 'Gamba', 'Ndele', 'Tsogni', 'Boende', 'Aripuana', 'Gaoua', 'San Francisco Del Mar', 'Amapa'].

# %%
hotel_df.head(20)
# Out:
#                      City Country  Max Temp      Lat       Lng  \
# 2              Georgetown      MY     78.89   5.4112  100.3354
# 4                   Vaini      TO     78.96 -21.2000 -175.2000
# 5      Sao Felix Do Xingu      BR     85.44  -6.6447  -51.9950
# 9                  Atuona      PF     78.75  -9.8000 -139.0333
# 15              Kavaratti      IN     79.63  10.5669   72.6420
# 21               Pimentel      PE     79.09  -6.8367  -79.9342
# 24                 Castro      BR     78.55 -24.7911  -50.0119
# 25                Rikitea      PF     77.00 -23.1203 -134.9692
# 29                Isangel      VU     78.40 -19.5500  169.2667
# 33                 Avarua      CK     77.05 -21.2078 -159.7750
# 35                Salalah      OM     75.29  17.0151   54.0924
# 39           Puerto Ayora      EC     76.96  -0.7393  -90.3518
# 42             Butaritari      KI     81.00   3.0707  172.7902
# 46        Bambous Virieux      MU     79.21 -20.3428   57.7575
# 47                Cayenne      GF     77.04   4.9333  -52.3333
# 49  Mayor Pablo Lagerenza      PY     80.91 -19.9309  -60.7718
# 55          Alice Springs      AU     78.35 -23.7000  133.8833
# 58              Namatanai      PG     79.74  -3.6667  152.4333
# 65               Bengkulu      ID     75.24  -3.8004  102.2655
# 66         Saint-Philippe      RE     76.59 -21.3585   55.7679
#
#                                   Hotel Name
# 2                             Cititel Penang
# 4                        Keleti Beach Resort
# 5                          Rio Xingu Camping
# 9                                Villa Enata
# 15             Hotels in Lakshadweep Islands
# 21                         Casona Del Muelle
# 24                            CHACARA BAILLY
# 25                           People ThankYou
# 29                               Tanna Lodge
# 33                              Paradise Inn
# 35  HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# 39                 Finch Bay Galapagos Hotel
# 42                        Isles Sunset Lodge
# 46                            Casa Tia Villa
# 47                           Hôtel Le Dronmi
# 49
# 55                Desert Palms Alice Springs
# 58                     Seagulls Inn Namatani
# 65                      Grage Hotel Bengkulu
# 66              Chambres d'hôte "La Trinité"

# %%
hotel_df.dtypes
# Out:
# City           object
# Country        object
# Max Temp      float64
# Lat           float64
# Lng           float64
# Hotel Name     object
# dtype: object

# %%
hotel_df["Hotel Name"].isnull()
# Out:
# 2      False
# 4      False
# 5      False
# 9      False
# 15     False
#        ...
# 536    False
# 543    False
# 545    False
# 547    False
# 548    False
# Name: Hotel Name, Length: 157, dtype: bool

# %%
hotel_df.loc[2, "City"]
# Out:
# 'Georgetown'

# %%
hotel_df.describe()
# Out:
#          Max Temp         Lat         Lng
# count  157.000000  157.000000  157.000000
# mean    80.686369   -3.552740   11.078122
# std      3.982530   15.420733   88.691022
# min     75.040000  -41.869700 -175.200000
# 25%     77.320000  -16.483300  -60.633300
# 50%     79.920000   -3.432000   -1.755400
# 75%     82.670000    9.510000   92.750000
# max     89.820000   26.783300  172.790200

# %%
hotel_df.tail()
# Out:
#             City Country  Max Temp      Lat       Lng              Hotel Name
# 536       Panaba      MX     75.33  21.2833  -88.2667        Hotel California
# 543        Praia      CV     81.14  14.9215  -23.5087           LT Aparthotel
# 545  Mozarlandia      BR     82.78 -14.7447  -50.5706      Hotel Santa Mônica
# 547  Grand-Santi      GF     75.15   4.2500  -54.3833  Hotel La Villa Couacou
# 548         Sola      VU     82.26 -13.8833  167.5500      Leumerus Bungalows

# %%
preferred_cities_df.describe()
# Out:
#           City_ID         Lat         Lng    Max Temp    Humidity  Cloudiness  \
# count  157.000000  157.000000  157.000000  157.000000  157.000000  157.000000
# mean   294.082803   -3.552740   11.078122   80.686369   67.464968   59.312102
# std    173.310044   15.420733   88.691022    3.982530   21.451355   35.274356
# min      2.000000  -41.869700 -175.200000   75.040000   10.000000    0.000000
# 25%    127.000000  -16.483300  -60.633300   77.320000   59.000000   30.000000
# 50%    321.000000   -3.432000   -1.755400   79.920000   73.000000   68.000000
# 75%    457.000000    9.510000   92.750000   82.670000   84.000000   95.000000
# max    548.000000   26.783300  172.790200   89.820000   98.000000  100.000000
#
#        Wind Speed
# count  157.000000
# mean     7.471847
# std      4.880974
# min      0.000000
# 25%      3.940000
# 50%      6.150000
# 75%     10.510000
# max     23.020000

# %%
hotel_df.loc[hotel_df['City'] == "Tsogni"]
# Out:
#        City Country  Max Temp     Lat      Lng Hotel Name
# 340  Tsogni      GA     78.08 -2.7942  10.0988

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
hotels = requests.get(base_url, params=params).json()

# %%
hotels
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -13.8766614, 'lng': 167.5533365},
#     'viewport': {'northeast': {'lat': -13.8753755697085,
#       'lng': 167.5549646802915},
#      'southwest': {'lat': -13.8780735302915, 'lng': 167.5522667197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Leumerus Bungalows',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 635,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102931619045693439239">Leumerus Bungalows</a>'],
#      'photo_reference': 'Aap_uEAuvxfETnnxq2ZMD0lF1JdYkk4K1GvQHIzk7uXNOb4-VK2J2SXOeulWBDZKJD-efur4x57S1pmC8ZCDAe5usuhjC_X8GCmWaeVsf7t0xNqj5MbJUe94oaTvsAFm19Vx1yqnDnpA7vex2GV37b67suwAhvI6DwpHbrEDMUB20H_DWllR',
#      'width': 960}],
#    'place_id': 'ChIJBUwSvtHh8G4RZkSKhnBTKS8',
#    'plus_code': {'compound_code': '4HF3+88 Sola, Vanuatu',
#     'global_code': '5VR94HF3+88'},
#    'rating': 3,
#    'reference': 'ChIJBUwSvtHh8G4RZkSKhnBTKS8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Vanua Lava, Sola'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -13.8755027, 'lng': 167.5509545},
#     'viewport': {'northeast': {'lat': -13.8740776697085,
#       'lng': 167.5524050302915},
#      'southwest': {'lat': -13.8767756302915, 'lng': 167.5497070697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Ulkel Guest House',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJyegKyAfh8G4REPbgQ7aLHb4',
#    'plus_code': {'compound_code': '4HF2+Q9 Sola, Vanuatu',
#     'global_code': '5VR94HF2+Q9'},
#    'reference': 'ChIJyegKyAfh8G4REPbgQ7aLHb4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Vanua Lava, Sola'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -13.875448, 'lng': 167.5515124},
#     'viewport': {'northeast': {'lat': -13.87416416970849,
#       'lng': 167.5527744302915},
#      'southwest': {'lat': -13.8768621302915, 'lng': 167.5500764697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Wilkins Guest House',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJeQeyY_Th8G4RlUhW__6Xwjg',
#    'plus_code': {'compound_code': '4HF2+RJ Sola, Vanuatu',
#     'global_code': '5VR94HF2+RJ'},
#    'reference': 'ChIJeQeyY_Th8G4RlUhW__6Xwjg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Vanua Lava Island, Sola'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -13.874219, 'lng': 167.5502464},
#     'viewport': {'northeast': {'lat': -13.8728457697085,
#       'lng': 167.5516286802915},
#      'southwest': {'lat': -13.8755437302915, 'lng': 167.5489307197086}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Seina Bungalow',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107152169228663401555">Andrew Tungon</a>'],
#      'photo_reference': 'Aap_uECmdqfIcxMtdmxyquC3lQ5RM6k50ZNPgE2UURW_ORpUwJA8XUYaovfyDjhmYGmK_hiaMYmKMoANrDPrRIvW5SeOqNtJAmK6vReDeoHMO70ta_LzMKZzwGi6HgXnVBqVpPseVmKl3GwhkjUmvceEJm7loS0BflCR-7R7EqIxKaPTwNX_',
#      'width': 4000}],
#    'place_id': 'ChIJ_6Q5zGbh8G4Ru8cVZycP-Lg',
#    'plus_code': {'compound_code': '4HG2+83 Sola, Vanuatu',
#     'global_code': '5VR94HG2+83'},
#    'rating': 3,
#    'reference': 'ChIJ_6Q5zGbh8G4Ru8cVZycP-Lg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Provincial headquarter, Sola'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -13.8724612, 'lng': 167.5504476},
#     'viewport': {'northeast': {'lat': -13.8714669197085,
#       'lng': 167.5513321302915},
#      'southwest': {'lat': -13.8741648802915, 'lng': 167.5486341697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Eliezer Travel Lodge',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107152169228663401555">Andrew Tungon</a>'],
#      'photo_reference': 'Aap_uEDR1bUm6r9hSFnzbCylaO-u8fKeMQarrQakbF_Xptmev5nkdzvffEi0G7SP2LlIVa8iTyJ4yfnXSdvshMbzeEwNo-hw9Y-nHlboNW5_AdLheqwWYHPrR50v9qF1LY8R48GRlLk3IZ88l2ZXrygX7P87Qg6_myyCSwgfQkXlzitvUsCz',
#      'width': 4000}],
#    'place_id': 'ChIJHRTUEQnn8G4RZmSIlAOTUlM',
#    'plus_code': {'compound_code': '4HH2+25 Sola, Vanuatu',
#     'global_code': '5VR94HH2+25'},
#    'rating': 4,
#    'reference': 'ChIJHRTUEQnn8G4RZmSIlAOTUlM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Vanua Lava Island, Sola'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -13.8673548, 'lng': 167.541996},
#     'viewport': {'northeast': {'lat': -13.8661170197085,
#       'lng': 167.5431805302915},
#      'southwest': {'lat': -13.8688149802915, 'lng': 167.5404825697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Whispering Bungalows',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2560,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110290347980642533391">Whispering Bungalows</a>'],
#      'photo_reference': 'Aap_uECMvzD5_AnuvTCZpA3vE2ISGmPpBnUcTr_krrLopg-eTVhCLy3OYVX4W79x07ZTwkvYknZPBsoSuc8XvMV7FRij_wMTqql96VDigaZzgYdykQllRSyWtAOx5r3cInVnByP4Eokw5_eVmrAi1A32EC8Jl_oQfBJ1srkNgDkUjmdBG1Wx',
#      'width': 1920}],
#    'place_id': 'ChIJd2X354Hn8G4RKUWFYxbywso',
#    'plus_code': {'compound_code': '4GMR+3Q Sola, Vanuatu',
#     'global_code': '5VR94GMR+3Q'},
#    'reference': 'ChIJd2X354Hn8G4RKUWFYxbywso',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Airport Road, Sola'}],
#  'status': 'OK'}
